# %%
import pandas as pd

# %%
for index,row in df2.iterrows():
    participant=row['ID']
    ontology = row['Ontologies']
    Visualization = row['Visualization']
    Task_Sucess = row['Task_Success']
    Time_On_Task = row['Time_On_Task']
    
    print(participant,ontology,Visualization,Time_On_Task)
    string1 = ("D:\Data Visualisation\Archive"+"\\" +participant+ "\\"+ participant+".graphFXD.txt")
    #string2= (string1 + "\\" + participant  + participant + '.graphFXD.txt')
    print(string1)         
    df = pd.read_csv(string1, sep="\t",header=None)
    df.columns=['No', 'Time', 'Duration', 'Screen X', 'Screen Y']                
    df[['participant','Ontologies','Visualization','Task_Sucess','Time_On_Task']] = pd.DataFrame([[participant,ontology,Visualization,Task_Sucess,Time_On_Task]],index = df.index)
    df.to_csv("D:/Data Visualisation/newFileSarita/"+participant+".csv")                
                     
                     
                     #df_all_cols = pd.concat([df, df2], axis = 1)
   #print (row['ID'], row['Ontologies'])
# Out:
# p2 1 2 19
# D:\Data Visualisation\Archive\p2\p2.graphFXD.txt
# p4 1 2 12
# D:\Data Visualisation\Archive\p4\p4.graphFXD.txt
# p6 1 2 26
# D:\Data Visualisation\Archive\p6\p6.graphFXD.txt
# p10 1 2 17
# D:\Data Visualisation\Archive\p10\p10.graphFXD.txt
# p12 1 2 17
# D:\Data Visualisation\Archive\p12\p12.graphFXD.txt
# p14 1 2 15
# D:\Data Visualisation\Archive\p14\p14.graphFXD.txt
# p16 1 2 28
# D:\Data Visualisation\Archive\p16\p16.graphFXD.txt
# p18 1 2 21
# D:\Data Visualisation\Archive\p18\p18.graphFXD.txt
# p20 1 2 30
# D:\Data Visualisation\Archive\p20\p20.graphFXD.txt
# p24 1 2 32
# D:\Data Visualisation\Archive\p24\p24.graphFXD.txt
# p28 1 2 10
# D:\Data Visualisation\Archive\p28\p28.graphFXD.txt
# p30 1 2 23
# D:\Data Visualisation\Archive\p30\p30.graphFXD.txt
# p32 1 2 21
# D:\Data Visualisation\Archive\p32\p32.graphFXD.txt
# p34 1 2 38
# D:\Data Visualisation\Archive\p34\p34.graphFXD.txt
# p36 1 2 21
# D:\Data Visualisation\Archive\p36\p36.graphFXD.txt

# %%
df = pd.read_csv("D:\Data Visualisation\Archive\"+participant+"\"+ participant+".graphFXD.txt", sep="\t",header=None)

# %%
df
# Out:
#        0       1    2     3    4
# 0      1     475  100   632  405
# 1      2    4084  100   285  197
# 2      3    4622  339    72  208
# 3      4    7792  199   304  978
# 4      5    8490  120   389  915
# 5      6    8669  100   405  917
# 6      7    9267  100    77  195
# 7      8    9387  379    71  212
# 8      9    9945  219   273  216
# 9     10   12876  100  1054  774
# 10    11   14611  199  1072  749
# 11    12   15867  120  1046  785
# 12    13   19615  140   279  201
# 13    14   20313  139   248  223
# 14    15   20472  100   269  177
# 15    16   20612  100   297  181
# 16    17   27690  179    83  190
# 17    18   28407  159   277  995
# 18    19   30640  160   388  903
# 19    20   31577  120   425  901
# 20    21   32933  120   408  838
# 21    22   42802  100   281  241
# 22    23   43600  100   304  186
# 23    24   46331  199   425  183
# 24    25   46550  100   433  197
# 25    26   46770  179   505  182
# 26    27   47966  120   701  283
# ...

# %%
df.columns=['No', 'Time', 'Duration', 'Screen X', 'Screen Y']

# %%
df
# Out:
#       No    Time  Duration  Screen X  Screen Y
# 0      1     475       100       632       405
# 1      2    4084       100       285       197
# 2      3    4622       339        72       208
# 3      4    7792       199       304       978
# 4      5    8490       120       389       915
# 5      6    8669       100       405       917
# 6      7    9267       100        77       195
# 7      8    9387       379        71       212
# 8      9    9945       219       273       216
# 9     10   12876       100      1054       774
# 10    11   14611       199      1072       749
# 11    12   15867       120      1046       785
# 12    13   19615       140       279       201
# 13    14   20313       139       248       223
# 14    15   20472       100       269       177
# 15    16   20612       100       297       181
# 16    17   27690       179        83       190
# 17    18   28407       159       277       995
# 18    19   30640       160       388       903
# ...

# %%
p1	2	2	0.52173913	38

# %%
df.insert(column() "Participant")
# Out:
#   File "<ipython-input-19-021cacc553c7>", line 1
#     df.insert(column "Participant")
#                                  ^
# SyntaxError: invalid syntax

# %%
df2 = pd.read_csv("D:\Data Visualisation\Asgn2\o1v2.csv")

df2
# Out:
#      ID  Ontologies  Visualization  Task_Success  Time_On_Task
# 0    p2           1              2      0.347826            19
# 1    p4           1              2      0.391304            12
# 2    p6           1              2      0.869565            26
# 3   p10           1              2      0.608696            17
# 4   p12           1              2      0.304348            17
# 5   p14           1              2      0.521739            15
# 6   p16           1              2      0.521739            28
# 7   p18           1              2      0.739130            21
# 8   p20           1              2      0.391304            30
# 9   p24           1              2      0.565217            32
# 10  p28           1              2      0.521739            10
# 11  p30           1              2      0.391304            23
# 12  p32           1              2      0.304348            21
# 13  p34           1              2      0.608696            38
# ...

# %%
string = df2.iloc[:,0]
print(string)
# Out:
# 0      p2
# 1      p4
# 2      p6
# 3     p10
# 4     p12
# 5     p14
# 6     p16
# 7     p18
# 8     p20
# 9     p24
# 10    p28
# 11    p30
# 12    p32
# 13    p34
# 14    p36
# Name: ID, dtype: object

# %%
df.assign(**{'col_new_1': np.nan, 'col2_new_2': 'dogs', 'col3_new_3': 3})

# %%
p3
2
2
0.391304
50

# %%
df[['participant','Ontologies','Visualization','Task_Sucess','Time_On_Task']] = pd.DataFrame([['p4','1','2','0.391304','12']],index = df.index)

# %%
df
# Out:
#       No    Time  Duration  Screen X  Screen Y participant Ontologies  \
# 0      1     475       100       632       405          p4          1
# 1      2    4084       100       285       197          p4          1
# 2      3    4622       339        72       208          p4          1
# 3      4    7792       199       304       978          p4          1
# 4      5    8490       120       389       915          p4          1
# 5      6    8669       100       405       917          p4          1
# 6      7    9267       100        77       195          p4          1
# 7      8    9387       379        71       212          p4          1
# 8      9    9945       219       273       216          p4          1
# 9     10   12876       100      1054       774          p4          1
# 10    11   14611       199      1072       749          p4          1
# 11    12   15867       120      1046       785          p4          1
# ...

# %%
df.to_csv("D:/Data Visualisation/Asgn2/fixp4.csv")

# %%
data_frames= []

# %%
df = pd.read_csv("D:\\Data Visualisation\\newFileShraddha\\groupO1V1.csv")
df
# Out:
#           X     Y  dilation
# 0      1005    60    3.7745
# 1        78   237    3.7175
# 2       246   207    3.6625
# 3       298   198    3.6650
# 4       909  1002    3.6195
# 5       507   559    3.7810
# 6      1012   986    3.6555
# 7      1046   997    3.6755
# 8       739   584    3.8295
# 9        90   592    3.7470
# 10       83   612    3.6430
# 11       58   485    3.5885
# 12      311   175    3.5195
# 13       79   201    3.5675
# 14       66   232    3.4925
# 15       64   230    3.4475
# 16      240   205    3.5230
# 17       62   202    3.4500
# 18       88   566    3.5755
# 19       90   542    3.6350
# 20       95   534    3.6130
# 21       85   590    3.6350
# 22       95   600    3.6975
# 23      185   158    3.6635
# 24       96   599    3.6215
# 25       89   535    3.7020
# 26       83   517    3.6645
# 27      720   544    3.6670
# 28      934   974    3.4505
# 29      764   282    3.4975
# ...     ...   ...       ...
# 32946   687   648    3.9065
# ...

# %%
df['dilation'].mean()
# Out:
# 3.8669230197719626
